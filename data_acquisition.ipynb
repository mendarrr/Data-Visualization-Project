# %%
import sys
print(sys.executable)
# Out:
# c:\Users\User\Data-Visualization-Project\.venv\Scripts\python.exe

# %%
import gdown

gdown.download('https://drive.google.com/uc?id=1cug4qWE6qFArHmYwcXUdDMaJIfmUzAZD', 'data/raw/Global Health Statistics.csv', quiet=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 import gdown
#       2
# ----> 3 gdown.download('https://drive.google.com/uc?id=1cug4qWE6qFArHmYwcXUdDMaJIfmUzAZD', 'data/raw/Global Health Statistics.csv', quiet=False)
#
# File c:\Users\User\Data-Visualization-Project\.venv\Lib\site-packages\gdown\download.py:337, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress)
#     334     return output
#     336 existing_tmp_files = []
# --> 337 for file in os.listdir(osp.dirname(output) or "."):
#     338     if file.startswith(osp.basename(output)) and file.endswith(".part"):
#     339         existing_tmp_files.append(osp.join(osp.dirname(output), file))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'data/raw'

# %%
import os
os.chdir(r'C:\Users\User\Data-Visualization-Project')
print(os.getcwd())
# Set working directory to your project folder
os.chdir(r'C:\Users\User\Data-Visualization-Project')

# Confirm you are in the right place
print(os.getcwd())
# Out:
# C:\Users\User\Data-Visualization-Project
# C:\Users\User\Data-Visualization-Project

# %%
import gdown

gdown.download('https://drive.google.com/uc?id=1cug4qWE6qFArHmYwcXUdDMaJIfmUzAZD', 'data/raw/Global Health Statistics.csv', quiet=False)
print(df.columns.tolist())
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1cug4qWE6qFArHmYwcXUdDMaJIfmUzAZD
# From (redirected): https://drive.google.com/uc?id=1cug4qWE6qFArHmYwcXUdDMaJIfmUzAZD&confirm=t&uuid=c81cf138-df68-4e12-b761-6a655a03e777
# To: C:\Users\User\Data-Visualization-Project\data\raw\Global Health Statistics.csv
# 100%|██████████| 134M/134M [00:32<00:00, 4.17MB/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 import gdown
#       2
#       3 gdown.download('https://drive.google.com/uc?id=1cug4qWE6qFArHmYwcXUdDMaJIfmUzAZD', 'data/raw/Global Health Statistics.csv', quiet=False)
# ----> 4 print(df.columns.tolist())
#
# NameError: name 'df' is not defined

# %%
import os
import pandas as pd

# Fix working directory
os.chdir(r'C:\Users\User\Data-Visualization-Project')

# Load dataset
df = pd.read_csv('data/raw/Global Health Statistics.csv')
print(df.columns.tolist())
# Out:
# ['Country', 'Year', 'Disease Name', 'Disease Category', 'Prevalence Rate (%)', 'Incidence Rate (%)', 'Mortality Rate (%)', 'Age Group', 'Gender', 'Population Affected', 'Healthcare Access (%)', 'Doctors per 1000', 'Hospital Beds per 1000', 'Treatment Type', 'Average Treatment Cost (USD)', 'Availability of Vaccines/Treatment', 'Recovery Rate (%)', 'DALYs', 'Improvement in 5 Years (%)', 'Per Capita Income (USD)', 'Education Index', 'Urbanization Rate (%)']

# %%
# See all column names
print(df.columns.tolist())
# Out:
# ['Country', 'Year', 'Disease Name', 'Disease Category', 'Prevalence Rate (%)', 'Incidence Rate (%)', 'Mortality Rate (%)', 'Age Group', 'Gender', 'Population Affected', 'Healthcare Access (%)', 'Doctors per 1000', 'Hospital Beds per 1000', 'Treatment Type', 'Average Treatment Cost (USD)', 'Availability of Vaccines/Treatment', 'Recovery Rate (%)', 'DALYs', 'Improvement in 5 Years (%)', 'Per Capita Income (USD)', 'Education Index', 'Urbanization Rate (%)']

# %%
#Resolve project root regardless of whether notebook is run from /notebooks or /


#If the file is missing, download it from Google Drive automatically


#Direct file download — replace FILE_ID with the actual file ID from the Drive link

# %%
# Quick No-Errors Check
